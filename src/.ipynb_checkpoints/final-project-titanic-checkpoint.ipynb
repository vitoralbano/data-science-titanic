# %% [markdown]
# # Data Science I - Projeto final

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('titanic-data-6.csv')

# %% [markdown]
# ## Perguntas (Questions)

# %% [markdown]
#     1. Quais são os números de sobreviventes?
#     2. Em qual classe havia mais familiares?
#     3. Qual é o número de crianças a bordo?
#     4. Qual é a proporção de crianças por gênero?
#     5. Qual é a proporção de crianças por classe?
#     6. Qual é a proporção de crianças que sobreviveram?

# %% [markdown]
# ## Preparar dados (Wrangle data)

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df['Sex'].nunique()
# Out:
# 2

# %%
# Checking if exists null fields
df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
# Filling null ages with mean
df['Age'].fillna(round(df['Age'].mean()), inplace=True)

# %%
# Cheking if are there passengers without on board place and that weren't survived.
df[df['Survived'] == 0]['Embarked'].isnull().any().sum()
# Out:
# 0

# %%
# Removing passengers that weren't on board or without boarding place. No one of them were checked as not survived.
df['Embarked'].dropna(how='any', inplace=True)

# %%
# Removing the 'Ticket' column, it doesn't look be an essencial info
df.drop(labels='Ticket', axis=1, inplace=True)

# %%
# Changing 'Embarked' column abbreviated values to full values
embarked_places = {'S': 'Southampton', 'C': 'Cherbourg', 'Q': 'Queenstown'}
df['Embarked'].replace(embarked_places.keys(), embarked_places.values(), inplace=True)

# %%
survived = {'0':'No', '1':'Yes'}
df['Survived'] = df['Survived'].astype(str).replace(survived.keys(),survived.values())

# %%
def age_category(age):
    # Used as reference:
    # https://www.statcan.gc.ca/eng/concepts/definitions/age2
    if(age < 15):
        return 'Children'
    elif(age < 25):
        return 'Youth'
    elif(age < 65):
        return 'Adult'
    else:
        return 'Senior'
    
df['AgeCategory'] = df['Age'].apply(age_category)

# %%
df.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1       No       3
# 1            2      Yes       1
# 2            3      Yes       3
# 3            4      Yes       1
# 4            5       No       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch     Fare Cabin     Embarked AgeCategory
# 0      0   7.2500   NaN  Southampton       Youth
# 1      0  71.2833   C85    Cherbourg       Adult
# 2      0   7.9250   NaN  Southampton       Adult
# 3      0  53.1000  C123  Southampton       Adult
# 4      0   8.0500   NaN  Southampton       Adult

# %% [markdown]
# ## Explorar (Explore)

# %%
pd.plotting.scatter_matrix(df[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']], figsize=(15,15));

# %%
df.hist(figsize=(15,15));

# %%
plt.close('all')
sns.set_style('whitegrid')

# %% [markdown]
# ### 1. Quais são os números de sobreviventes? Geral, por classe, gênero e taxa

# %% [markdown]
# #### Sobreviventes

# %%
title = 'TITANIC SURVIVORS\nTotal passengers sample: {count}'.format(count=df.shape[0])

fig, ax = plt.subplots(1, 2)
fig.suptitle(title, fontsize='x-large', horizontalalignment='center', verticalalignment='bottom')

# Redismensionar o layout automaticamente
plt.tight_layout()
# Ajuste de posicionamento em relação ao topo
plt.subplots_adjust(top=.9)
# Definição da largura dos gráficos
fig.set_figwidth(14)

# Definição do dataframe de proporções
df_proportions = df['Survived'].value_counts(normalize=True).reset_index().rename(columns={'index':'Survived','Survived':'Proportions'})
df_proportions['Proportions'] = df_proportions['Proportions'] * 100

# Definição dos títulos
ax[0].set_title('Survivors count')
ax[1].set_title('Survivors proportions')

# Gerar os gráficos com seaborn
sns.countplot(data=df, x='Survived', ax=ax[0], palette='Blues_d')
sns.barplot(data=df_proportions, x='Survived', y='Proportions', ax=ax[1], palette='Blues_d');

# %%
df_proportions
# Out:
#   Survived  Proportions
# 0       No    61.616162
# 1      Yes    38.383838

# %% [markdown]
# #### Sobreviventes por gênero e classe

# %%
ax_by_class = sns.factorplot(data=df, x='Survived', hue='Sex', col='Pclass', kind='count', palette='Blues_d')
ax_by_class.set_titles('Class {col_name}');

# %%
df_filtered = df.groupby(['Pclass', 'Sex', 'Survived']).count()['Age'].reset_index()
df_filtered.rename(columns={'Age':'Count'}, inplace=True)

df_filtered
# Out:
#     Pclass     Sex Survived  Count
# 0        1  female       No      3
# 1        1  female      Yes     91
# 2        1    male       No     77
# 3        1    male      Yes     45
# 4        2  female       No      6
# 5        2  female      Yes     70
# 6        2    male       No     91
# 7        2    male      Yes     17
# 8        3  female       No     72
# 9        3  female      Yes     72
# 10       3    male       No    300
# 11       3    male      Yes     47

# %% [markdown]
# #### Sobrevivents por local de embarque

# %%
ax_by_class = sns.factorplot(data=df, x='Survived', hue='Sex', col='Embarked', kind='count', palette='Blues_d')
ax_by_class.set_titles('{col_name}');

# %% [markdown]
# #### Local de embarque por classe e gênero

# %%
ax_by_class = sns.factorplot(data=df, x='Pclass', hue='Sex', col='Embarked', kind='count', palette='Blues_d')
ax_by_class.set_titles('{col_name}');

# %% [markdown]
# #### Classificação de idade por classe, local de embarque e sobreviventes

# %%
ax_by_class = sns.factorplot(data=df, x='AgeCategory', hue='Survived', col='Pclass', kind='count', palette='Blues_d')
ax_by_class.set_titles('Class {col_name}');

# %%
ax_by_class = sns.factorplot(data=df, x='AgeCategory', hue='Survived', col='Embarked', kind='count', palette='Blues_d')
ax_by_class.set_titles('{col_name}');

# %%
ax_by_class = sns.factorplot(data=df, x='AgeCategory', hue='Sex', col='Embarked', kind='count', palette='Blues_d')
ax_by_class.set_titles('{col_name}');

# %%
fig, ax = plt.subplots(figsize=(12,12))
sns.violinplot(data=df, ax=ax, x='Pclass', y='Age', col='Pclass', hue='Sex', split=True, inner='quart', palette='Blues_d');

# %% [markdown]
# #### Contagem de familiares (Pais/Filhos) por classe

# %%
ax_by_class = sns.factorplot(data=df, x='Parch', col='Pclass', kind='count', palette='Blues_d')
ax_by_class.set_titles('Class {col_name}');

# %% [markdown]
# #### Contagem de irmãos/cônjuges por classe

# %%
ax_by_class = sns.factorplot(data=df, x='SibSp', col='Pclass', kind='count', palette='Blues_d')
ax_by_class.set_titles('Class {col_name}');

# %%
df_parch_sibsp = df.groupby('Pclass')[['Parch', 'SibSp']].agg(['mean', 'count', 'max', 'sum']).reset_index()
df_parch_sibsp
# Out:
#   Pclass     Parch                    SibSp
#               mean count max  sum      mean count max  sum
# 0      1  0.356481   216   4   77  0.416667   216   3   90
# 1      2  0.380435   184   3   70  0.402174   184   3   74
# 2      3  0.393075   491   6  193  0.615071   491   8  302

# %%
# Definir novos indexes
index_columns =[]
for (name_1, name_2) in df_parch_sibsp.columns.ravel():
    if(name_2):
        index_columns.append('{}_{}'.format(name_1, name_2))
    else:
        index_columns.append(name_1)

df_parch_sibsp.columns = index_columns

# %%
df_parch_sibsp['Parch_proportion'] = df_parch_sibsp['Parch_sum'] / df_parch_sibsp['Parch_count']
df_parch_sibsp['SibSp_proportion'] = df_parch_sibsp['SibSp_sum'] / df_parch_sibsp['SibSp_count']

df_parch_sibsp
# Out:
#    Pclass  Parch_mean  Parch_count  Parch_max  Parch_sum  SibSp_mean  \
# 0       1    0.356481          216          4         77    0.416667
# 1       2    0.380435          184          3         70    0.402174
# 2       3    0.393075          491          6        193    0.615071
#
#    SibSp_count  SibSp_max  SibSp_sum  Parch_proportion  SibSp_proportion
# 0          216          3         90          0.356481          0.416667
# 1          184          3         74          0.380435          0.402174
# 2          491          8        302          0.393075          0.615071

# %%
sns.factorplot(data=df_parch_sibsp, x='Pclass', y='Parch_proportion', kind='bar', palette='Blues_d')

# %%
sns.factorplot(data=df_parch_sibsp, x='Pclass', y='SibSp_proportion', kind='bar', palette='Blues_d')

# %%
df_age = df['AgeCategory'].value_counts().reset_index()
df_age['Proportions'] = df['AgeCategory'].value_counts(normalize=True).reset_index()['AgeCategory']
df_age
# Out:
#       index  AgeCategory  Proportions
# 0     Adult          602     0.675645
# 1     Youth          200     0.224467
# 2  Children           78     0.087542
# 3    Senior           11     0.012346

# %% [markdown]
# #### Contagem de pessoas por gênero em cada classe

# %%
ax_by_class = sns.factorplot(data=df, x='Sex', col='Pclass', kind='count', palette='Blues_d')
ax_by_class.set_titles('Class {col_name}');

# %%
sns.violinplot(data=df, x='Sex',y='Pclass', hue='Sex', split=True, inner='quart', palette='Blues_d');

# %%
df_surv = df[df['Survived'] == 'Yes']
df_surv.groupby('Pclass')['Survived'].count().reset_index()

df_surv['Proportion'] = df_surv['Survived'] / df.groupby('Pclass')['Survived'].count().reset_index()['Survived']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\ProgramData\Anaconda3\envs\py3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     675         try:
# --> 676             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     677         except TypeError:
#
# D:\ProgramData\Anaconda3\envs\py3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     203     if use_numexpr:
# --> 204         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     205     return _evaluate_standard(op, op_str, a, b)
#
# D:\ProgramData\Anaconda3\envs\py3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      63     with np.errstate(all='ignore'):
# ---> 64         return op(a, b)
#      65
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# D:\ProgramData\Anaconda3\envs\py3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#     699             with np.errstate(all='ignore'):
# --> 700                 return na_op(lvalues, rvalues)
#     701         except Exception:
#
# D:\ProgramData\Anaconda3\envs\py3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     681                 mask = notna(x) & notna(y)
# --> 682                 result[mask] = op(x[mask], _values_from_object(y[mask]))
#     683             elif isinstance(x, np.ndarray):
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-2879717779ed> in <module>()
#       1 df_surv = df[df['Survived'] == 'Yes']
#       2 df_surv.groupby('Pclass')['Survived'].count().reset_index()
# ----> 3 df_surv['Proportion'] = df_surv['Survived'] / df.groupby('Pclass')['Survived'].count().reset_index()['Survived']
#
# D:\ProgramData\Anaconda3\envs\py3\lib\site-packages\pandas\core\ops.py in wrapper(left, right, name, na_op)
#     737                 lvalues = lvalues.values
#     738
# --> 739         result = wrap_results(safe_na_op(lvalues, rvalues))
#     740         return construct_result(
#     741             left,
#
# D:\ProgramData\Anaconda3\envs\py3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#     708                 if is_object_dtype(lvalues):
#     709                     return libalgos.arrmap_object(lvalues,
# --> 710                                                   lambda x: op(x, rvalues))
#     711             raise
#     712
#
# pandas/_libs/algos_common_helper.pxi in pandas._libs.algos.arrmap_object()
#
# D:\ProgramData\Anaconda3\envs\py3\lib\site-packages\pandas\core\ops.py in <lambda>(x)
#     708                 if is_object_dtype(lvalues):
#     709                     return libalgos.arrmap_object(lvalues,
# --> 710                                                   lambda x: op(x, rvalues))
#     711             raise
#     712
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %% [markdown]
# ## Perguntas
#     1. Quais são os números de sobreviventes?
#     2. Em qual classe havia mais familiares?
#     3. Qual é o número de crianças a bordo?
#     4. Qual é a proporção de crianças por gênero?
#     5. Qual é a proporção de crianças por classe?
#     6. Qual é a proporção de crianças que sobreviveram?

# %% [markdown]
# ## Conclusões
# Vale ressaltar que todas as informações abaixo estão baseadas em uma amostra de 891 pessoas a bordo.
#
#     1. Com base na amostra analisada, sobreviveram apenas 38,4% (342) do total de 891 pessoas a bordo, 61,6% (549) morreram.
#     2. É possível identificar que a terceira classe apresenta a maior proporção de irmãos/conjuges (61,5%) e pais/filhos (39,3%)
#     3. Haviam 78 crianças a bordo, representando 8,7% do total
#     4.
